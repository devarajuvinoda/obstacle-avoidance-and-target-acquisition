# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
datax=pd.read_csv("path_X[-0.990588]")
datay=pd.read_csv("path_Y[-0.990588]")
plt.figure(figsize=(10,10))
plt.plot(datay,datax)

plt.plot(0.354726,-0.413149,marker='o',markersize=10,color='green')
plt.annotate("   START",(0.354726,-0.413149))
plt.plot(0.12,.25,marker='x',markersize=10,color='red')
plt.annotate("   GOAL",(0.12,.25))
labels=['path traced by E-puck robot']
plt.legend(labels)

plt.plot(0.45,.13,marker='*',markersize=10,color='red')
plt.annotate("   Rock",(0.45,.13))
plt.plot(-.24,.08,marker='*',markersize=10,color='red')
plt.annotate("   Wall",(-.24,.08))
plt.plot(0.22,-.32,marker='*',markersize=10,color='red')
plt.annotate("   Plastic Crate",(0.22,-.32))
plt.plot(0.08,-.1,marker='*',markersize=10,color='red')
plt.annotate("   Oil Barrel",(0.08,-.1))
# Out:
# Text(0.08, -0.1, '   Oil Barrel')

# %%
plt.figure(figsize=(10,10))
img = plt.imread("small_world_modified_9th_1.png")
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
# ax.imshow(img)
ax.imshow(img, extent=[-0.6, 0.6, -0.5, 0.5])


datax=pd.read_csv("path_X[-0.990588]")
datay=pd.read_csv("path_Y[-0.990588]")
plt.plot(datay,datax)

plt.plot(0.354726,-0.413149,marker='o',markersize=10,color='green')
plt.annotate("   START",(0.354726,-0.413149))
plt.plot(0.11,.23,marker='x',markersize=10,color='red')
plt.annotate("   GOAL",(0.12,.25))
labels=['path traced by E-puck robot']
plt.legend(labels)

# plt.plot(0.45,.13,marker='*',markersize=10,color='red')
# plt.annotate("   Rock",(0.45,.13))
# plt.plot(-.22,.09,marker='*',markersize=10,color='red')
# plt.annotate("   Wall",(-.24,.08))
# plt.plot(0.22,-.32,marker='*',markersize=10,color='red')
# plt.annotate("   Plastic Crate",(0.22,-.32))
# plt.plot(0.08,-.1,marker='*',markersize=10,color='red')
# plt.annotate("   Oil Barrel",(0.08,-.1))

# %%
plt.figure(figsize=(10,10))
img = plt.imread("small_world_modified_9th_1.png")
fig, ax = plt.subplots()
# fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
ax.imshow(img)

# %%
datax=pd.read_csv("path_X[-0.77143194]")
datay=pd.read_csv("path_Y[-0.77143194]")
plt.figure(figsize=(10,10))

plt.figure(figsize=(10,10))
img = plt.imread("small_world_modified_9th_1.png")
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 18.5)
# ax.imshow(img)
ax.imshow(img, extent=[-0.6, 0.6, -0.5, 0.5])

plt.plot(datay[-2230:],datax[-2230:])
plt.plot(0.354726,-0.413149,marker='o',markersize=10,color='green')
plt.annotate("   start",(0.354726,-0.413149))
plt.plot(0.19,.23,marker='x',markersize=10,color='red')
plt.annotate("   goal",(0.19,.23))
labels=['path traced by E-puck robot']
plt.legend(labels)


plt.plot(0.45,.13,marker='*',markersize=10,color='red')
plt.annotate("   Rock",(0.45,.13))
plt.plot(-.24,.08,marker='*',markersize=10,color='red')
plt.annotate("   Wall",(-.24,.08))
plt.plot(0.22,-.32,marker='*',markersize=10,color='red')
plt.annotate("   Plastic Crate",(0.22,-.32))
plt.plot(0.08,-.1,marker='*',markersize=10,color='red')
plt.annotate("   Oil Barrel",(0.08,-.1))
# Out:
# Text(0.08, -0.1, '   Oil Barrel')

# %%
datax=pd.read_csv("path_X[1.16693009]")
datay=pd.read_csv("path_Y[1.16693009]")
plt.figure(figsize=(10,10))
# plt.plot(datay,datax)
plt.plot(datay[-1800:],datax[-1800:])

plt.plot(0.354726,-0.413149,marker='o',markersize=10,color='green')
plt.annotate("   start",(0.354726,-0.413149))
plt.plot(0.11,.23,marker='x',markersize=10,color='red')
plt.annotate("   goal",(0.12,.25))
labels=['path traced by E-puck robot']
plt.legend(labels)


plt.plot(0.45,.13,marker='*',markersize=10,color='red')
plt.annotate("   Rock",(0.45,.13))
plt.plot(-.24,.08,marker='*',markersize=10,color='red')
plt.annotate("   Wall",(-.24,.08))
plt.plot(0.22,-.32,marker='*',markersize=10,color='red')
plt.annotate("   Plastic Crate",(0.22,-.32))
plt.plot(0.08,-.1,marker='*',markersize=10,color='red')
plt.annotate("   Oil Barrel",(0.08,-.1))
# Out:
# Text(0.08, -0.1, '   Oil Barrel')

# %%
datax=pd.read_csv("path_X[1.54806364]")
datay=pd.read_csv("path_Y[1.54806364]")
plt.figure(figsize=(10,10))
# plt.plot(datay,datax)
plt.plot(datay[-1260:],datax[-1260:])

plt.plot(0.354726,-0.413149,marker='o',markersize=10,color='green')
plt.annotate("   start",(0.354726,-0.413149))
plt.plot(0.11,.23,marker='x',markersize=10,color='red')
plt.annotate("   goal",(0.12,.25))
labels=['path traced by E-puck robot']
plt.legend(labels)


plt.plot(0.45,.13,marker='*',markersize=10,color='red')
plt.annotate("   Rock",(0.45,.13))
plt.plot(-.24,.08,marker='*',markersize=10,color='red')
plt.annotate("   Wall",(-.24,.08))
plt.plot(0.22,-.32,marker='*',markersize=10,color='red')
plt.annotate("   Plastic Crate",(0.22,-.32))
plt.plot(0.08,-.1,marker='*',markersize=10,color='red')
plt.annotate("   Oil Barrel",(0.08,-.1))
# Out:
# Text(0.08, -0.1, '   Oil Barrel')

# %%
datax=pd.read_csv("path_X[1.02673184]")
datay=pd.read_csv("path_Y[1.02673184]")
plt.figure(figsize=(10,10))
# plt.plot(datay,datax)
plt.plot(datay[-820:],datax[-820:])

plt.plot(0.354726,-0.413149,marker='o',markersize=10,color='green')
plt.annotate("   start",(0.354726,-0.413149))
plt.plot(0.11,.23,marker='x',markersize=10,color='red')
plt.annotate("   goal",(0.12,.25))
labels=['path traced by E-puck robot']
plt.legend(labels)


plt.plot(0.45,.13,marker='*',markersize=10,color='red')
plt.annotate("   Rock",(0.45,.13))
plt.plot(-.24,.08,marker='*',markersize=10,color='red')
plt.annotate("   Wall",(-.24,.08))
plt.plot(0.22,-.32,marker='*',markersize=10,color='red')
plt.annotate("   Plastic Crate",(0.22,-.32))
plt.plot(0.08,-.1,marker='*',markersize=10,color='red')
plt.annotate("   Oil Barrel",(0.08,-.1))
# Out:
# Text(0.08, -0.1, '   Oil Barrel')

# %%
datax=pd.read_csv("path_X[1.2587785]")
datay=pd.read_csv("path_Y[1.2587785]")
plt.figure(figsize=(10,10))
# plt.plot(datay,datax)
plt.plot(datay[-2850:],datax[-2850:])

plt.plot(0.354726,-0.413149,marker='o',markersize=10,color='green')
plt.annotate("   start",(0.354726,-0.413149))
plt.plot(0.11,.23,marker='x',markersize=10,color='red')
plt.annotate("   goal",(0.12,.25))
labels=['path traced by E-puck robot']
plt.legend(labels)


plt.plot(0.45,.13,marker='*',markersize=10,color='red')
plt.annotate("   Rock",(0.45,.13))
plt.plot(-.24,.08,marker='*',markersize=10,color='red')
plt.annotate("   Wall",(-.24,.08))
plt.plot(0.22,-.32,marker='*',markersize=10,color='red')
plt.annotate("   Plastic Crate",(0.22,-.32))
plt.plot(0.08,-.1,marker='*',markersize=10,color='red')
plt.annotate("   Oil Barrel",(0.08,-.1))
# Out:
# Text(0.08, -0.1, '   Oil Barrel')

# %%
datax=pd.read_csv("path_X[0.46958537]")
datay=pd.read_csv("path_Y[0.46958537]")
plt.figure(figsize=(10,10))
# plt.plot(datay,datax)
plt.plot(datay[-2850:],datax[-2850:])

plt.plot(0.354726,-0.413149,marker='o',markersize=10,color='green')
plt.annotate("   start",(0.354726,-0.413149))
plt.plot(0.11,.23,marker='x',markersize=10,color='red')
plt.annotate("   goal",(0.12,.25))
labels=['path traced by E-puck robot']
plt.legend(labels)


plt.plot(0.45,.13,marker='*',markersize=10,color='red')
plt.annotate("   Rock",(0.45,.13))
plt.plot(-.24,.08,marker='*',markersize=10,color='red')
plt.annotate("   Wall",(-.24,.08))
plt.plot(0.22,-.32,marker='*',markersize=10,color='red')
plt.annotate("   Plastic Crate",(0.22,-.32))
plt.plot(0.08,-.1,marker='*',markersize=10,color='red')
plt.annotate("   Oil Barrel",(0.08,-.1))
# Out:
# Text(0.08, -0.1, '   Oil Barrel')

# %%
score=pd.read_csv("scores.txt")
index=pd.read_csv("index.txt",header=None)
plt.figure(figsize=(10,10))
plt.ylim(-100,100)
plt.plot(index,score)
plt.plot([0,500],[0,0])
plt.xlabel("number of episodes")
plt.ylabel("reward")
# score=score.astype(float)
# score.plot()
# Out:
# Text(0, 0.5, 'reward')

# %%
index
# Out:
#        0
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 490  491
# 491  492
# 492  493
# 493  494
# 494  495
#
# [495 rows x 1 columns]

# %%
for i in score:
    print(i)
# Out:
#       -14.2
# 0    -15.26
# 1    -82.11
# 2    -11.79
# 3    -12.91
# 4    -16.68
# ..      ...
# 490  -82.25
# 491   -15.6
# 492   14.44
# 493  -16.99
# 494   27.03
#
# [495 rows x 1 columns]

# %%
plt.scatter(index, score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-260-ed7611183356> in <module>()
# ----> 1 plt.scatter(index, score)
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2893         verts=verts, edgecolors=edgecolors,
#    2894         plotnonfinite=plotnonfinite,
# -> 2895         **({"data": data} if data is not None else {}), **kwargs)
#    2896     sci(__ret)
#    2897     return __ret
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4430         # Process **kwargs to handle aliases, conflicts with explicit kwargs:
#    4431
# -> 4432         self._process_unit_info(xdata=x, ydata=y, kwargs=kwargs)
#    4433         x = self.convert_xunits(x)
#    4434         y = self.convert_yunits(y)
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2188
#    2189         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2190         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2191         return kwargs
#    2192
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2170                 # We only need to update if there is nothing set yet.
#    2171                 if not axis.have_units():
# -> 2172                     axis.update_units(data)
#    2173
#    2174             # Check for units in the kwargs, and if present update axis
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/axis.py in update_units(self, data)
#    1464         neednew = self.converter != converter
#    1465         self.converter = converter
# -> 1466         default = self.converter.default_units(data, self)
#    1467         if default is not None and self.units is None:
#    1468             self.set_units(default)
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/category.py in default_units(data, axis)
#     105         # the conversion call stack is default_units -> axis_info -> convert
#     106         if axis.units is None:
# --> 107             axis.set_units(UnitData(data))
#     108         else:
#     109             axis.units.update(data)
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/category.py in __init__(self, data)
#     174         self._counter = itertools.count()
#     175         if data is not None:
# --> 176             self.update(data)
#     177
#     178     @staticmethod
#
# /home/devu/.local/lib/python3.6/site-packages/matplotlib/category.py in update(self, data)
#     207         # check if convertible to number:
#     208         convertible = True
# --> 209         for val in OrderedDict.fromkeys(data):
#     210             # OrderedDict just iterates over unique values in data.
#     211             cbook._check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'numpy.ndarray'
